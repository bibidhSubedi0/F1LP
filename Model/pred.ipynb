# %%
import pandas as pd
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.metrics import mean_absolute_error

# %%
df = pd.read_csv("total.csv")
df.head()
# Out:
#   Driver      Constructor                   RaceName  DriverPointsSoFar  \
# 0    VER  Red Bull Racing         Bahrain Grand Prix                0.0
# 1    VER  Red Bull Racing  Emilia Romagna Grand Prix               77.0
# 2    VER  Red Bull Racing        Japanese Grand Prix               51.0
# 3    VER  Red Bull Racing      Australian Grand Prix               51.0
# 4    VER  Red Bull Racing          Monaco Grand Prix              102.0
#
#    ConstructorPointsSoFar  NextRacePosition  DriverWinRateThisSeason  \
# 0                     0.0                 1                 0.000000
# 1                   141.0                 1                 0.750000
# 2                    97.0                 1                 0.666667
# 3                    87.0                19                 1.000000
# 4                   170.0                 6                 0.800000
#
#    DriverPodiumRate  AverageQualifyingPosition  DriverExperienceYears  \
# 0          0.000000                        NaN                      9
# 1          0.750000                        1.0                      9
# 2          0.666667                        1.0                      9
# 3          1.000000                        1.0                      9
# 4          0.800000                        1.0                      9
#
#    DNFCountThisSeason  TeammateComparison
# 0                   0                 0.0
# 1                   1                13.0
# 2                   1                 5.0
# 3                   0                15.0
# 4                   1                34.0

# %%
X = df.drop(columns=['NextRacePosition'])
y = df['NextRacePosition']
groups = df['RaceName']

# %%
gss = GroupShuffleSplit(test_size=0.2, n_splits=1, random_state=42)
train_idx, test_idx = next(gss.split(X, y, groups=groups))

X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

# %%
cat_cols = ['Driver', 'Constructor', 'RaceName']
num_cols = [c for c in X.columns if c not in cat_cols]

# %%
preprocessor = ColumnTransformer([
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), cat_cols)
], remainder='passthrough')

# %%
model = HistGradientBoostingRegressor(max_depth=6, learning_rate=0.1, random_state=42)

# %%
pipeline = Pipeline([
    ('prep', preprocessor),
    ('model', model)
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Driver', 'Constructor',
#                                                    'RaceName'])])),
#                 ('model',
#                  HistGradientBoostingRegressor(max_depth=6, random_state=42))])

# %%
y_pred = pipeline.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 3.775362028182565

# %%
def predict_race_positions(race_df, pipeline):
    preds = pipeline.predict(race_df)
    race_df = race_df.copy()
    race_df['PredictedScore'] = preds
    # Sort by predicted score ascending (lower predicted position = better)
    race_df = race_df.sort_values(by='PredictedScore')
    # Assign predicted finishing positions 1..N
    race_df['PredictedPosition'] = range(1, len(race_df) + 1)
    return race_df[['Driver', 'PredictedScore', 'PredictedPosition']]

# %%
from scipy.stats import kendalltau, spearmanr

race_correlations = []
for race, grp in X_test.assign(TruePos=y_test).groupby('RaceName'):
    pred = pipeline.predict(grp)
    race_correlations.append(
        spearmanr(grp['TruePos'], pred).correlation
    )

print("Average Spearman correlation:", sum(race_correlations)/len(race_correlations))
# Out:
# Average Spearman correlation: 0.5235588972431078

# %%
new_race = pd.read_csv("to_pred.csv")
new_race
# Out:
#     Unnamed: 0 Driver      Constructor              RaceName  \
# 0            0    NOR          McLaren  Singapore Grand Prix
# 1            1    VER  Red Bull Racing  Singapore Grand Prix
# 2            2    RUS         Mercedes  Singapore Grand Prix
# 3            3    ANT         Mercedes  Singapore Grand Prix
# 4            4    ALB         Williams  Singapore Grand Prix
# 5            5    STR     Aston Martin  Singapore Grand Prix
# 6            6    HUL      Kick Sauber  Singapore Grand Prix
# 7            7    LEC          Ferrari  Singapore Grand Prix
# 8            8    PIA          McLaren  Singapore Grand Prix
# 9            9    HAM          Ferrari  Singapore Grand Prix
# 10          10    GAS           Alpine  Singapore Grand Prix
# 11          11    TSU  Red Bull Racing  Singapore Grand Prix
# 12          12    OCO     Haas F1 Team  Singapore Grand Prix
# 13          13    BEA     Haas F1 Team  Singapore Grand Prix
# 14          14    LAW     Racing Bulls  Singapore Grand Prix
# 15          15    BOR      Kick Sauber  Singapore Grand Prix
# 16          16    ALO     Aston Martin  Singapore Grand Prix
# 17          17    SAI         Williams  Singapore Grand Prix
# 18          18    DOO           Alpine  Singapore Grand Prix
# 19          19    HAD     Racing Bulls  Singapore Grand Prix
# 20          20    COL           Alpine  Singapore Grand Prix
#
#     DriverPointsSoFar  ConstructorPointsSoFar  NextRacePosition  \
# 0               284.0                   587.0               NaN
# 1               241.0                   255.0               NaN
# 2               202.0                   276.0               NaN
# 3                74.0                   276.0               NaN
# 4                70.0                    98.0               NaN
# 5                28.0                    58.0               NaN
# 6                37.0                    55.0               NaN
# 7               156.0                   263.0               NaN
# 8               303.0                   587.0               NaN
# 9               107.0                   263.0               NaN
# 10               19.0                    19.0               NaN
# 11               14.0                   255.0               NaN
# 12               24.0                    38.0               NaN
# 13               14.0                    38.0               NaN
# 14               30.0                    68.0               NaN
# 15               18.0                    55.0               NaN
# 16               30.0                    58.0               NaN
# 17               28.0                    98.0               NaN
# 18                0.0                    19.0               NaN
# 19               38.0                    68.0               NaN
# 20                0.0                    19.0               NaN
#
#     DriverWinRateThisSeason  DriverPodiumRate  AverageQualifyingPosition  \
# 0                  0.294118          0.764706                   3.352941
# 1                  0.235294          0.470588                   3.176471
# 2                  0.058824          0.411765                   4.588235
# 3                  0.000000          0.058824                   8.882353
# 4                  0.000000          0.000000                  11.470588
# 5                  0.000000          0.000000                  16.062500
# 6                  0.000000          0.058824                  16.000000
# 7                  0.000000          0.294118                   5.411765
# 8                  0.411765          0.823529                   2.529412
# 9                  0.000000          0.000000                   8.000000
# 10                 0.000000          0.000000                  13.235294
# 11                 0.000000          0.000000                  11.823529
# 12                 0.000000          0.000000                  15.411765
# 13                 0.000000          0.000000                  15.176471
# 14                 0.000000          0.000000                  13.176471
# 15                 0.000000          0.000000                  13.882353
# 16                 0.000000          0.000000                  10.764706
# 17                 0.000000          0.058824                  11.235294
# 18                 0.000000          0.000000                  15.500000
# 19                 0.000000          0.058824                   9.823529
# 20                 0.000000          0.000000                  16.454545
#
#     DriverExperienceYears  DNFCountThisSeason  TeammateComparison
# 0                       6                   2               -19.0
# 1                      10                   1               227.0
# 2                       6                   1               128.0
# 3                       0                   6              -128.0
# 4                       6                   5                42.0
# 5                       8                   7                -2.0
# 6                      15                   8                19.0
# 7                       7                   2                49.0
# 8                       2                   1                19.0
# 9                      18                   3               -49.0
# 10                      8                   8                19.0
# 11                      4                   7              -227.0
# 12                      9                   6                10.0
# 13                      0                   5               -10.0
# 14                      0                   5                -8.0
# 15                      0                   8               -19.0
# 16                     24                   6                 2.0
# 17                     10                   6               -42.0
# 18                      0                   3               -19.0
# 19                      0                   7                 8.0
# 20                      0                   7               -19.0

# %%
pred_scores = pipeline.predict(new_race)
new_race['PredictedScore'] = pred_scores

# %%
new_race = new_race.sort_values(by='PredictedScore')

# %%
new_race['PredictedPosition'] = range(1, len(new_race) + 1)

print(new_race[['Driver', 'PredictedScore', 'PredictedPosition']])
# Out:
#    Driver  PredictedScore  PredictedPosition
# 7     LEC        0.740167                  1
# 2     RUS        0.926422                  2
# 1     VER        2.711397                  3
# 8     PIA        4.681949                  4
# 9     HAM        6.433532                  5
# 0     NOR        7.168698                  6
# 3     ANT       10.069704                  7
# 19    HAD       10.070885                  8
# 14    LAW       12.023494                  9
# 13    BEA       12.104816                 10
# 10    GAS       12.768864                 11
# 15    BOR       13.230425                 12
# 16    ALO       13.357619                 13
# 6     HUL       13.485118                 14
# 11    TSU       13.985752                 15
# 12    OCO       14.569917                 16
# 5     STR       14.666100                 17
# 18    DOO       15.069761                 18
# 20    COL       15.188542                 19
# 17    SAI       15.613979                 20
# 4     ALB       17.358473                 21
